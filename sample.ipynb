# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import pandas as pd
import os

# %%
os.getcwd()
os.chdir('/Users/jelle/PycharmProjects/Hackathon 2024/data')

# %%
voertuigen_df = pd.read_csv('Gegevens bedrijventerrein(Voertuig info).csv')
bedrijven_df = pd.read_csv('Gegevens bedrijven (verdeling voertuigen).csv')

# %%
voertuigen_df.head()
# Out:
#                     Model Voertuigtype Brandstoftype  \
# 0                  DAF XF  Vrachtwagen        Diesel
# 1  Volkswagen Transporter    Bestelbus        Diesel
# 2       Volvo FH Electric  Vrachtwagen    Electrisch
# 3     Renault Kangoo Z.E.    Bestelbus    Electrisch
#
#    Brandstof verbruik L/100km  Brandstof verbruik L/1km  Tank capaciteit in L  \
# 0                        30.0                      0.30                1200.0
# 1                         7.0                      0.07                  70.0
# 2                         NaN                       NaN                   NaN
# 3                         NaN                       NaN                   NaN
#
#    Electriciteit verbruik kWh/100km  Electriciteit verbruik kWh/1km  \
# 0                            294.00                          2.9400
# 1                             68.60                          0.6860
# 2                              1.80                          0.0180
# ...

# %%
bedrijven_df.head()
# Out:
#             Bedrijfsnaam                   Producten      Sector  \
# 0            Best Trucks                Vrachtwagens  Automotive
# 1          Berkman Groep  Brandstoffen, tankstations     Energie
# 2        4 Fruit Company              Fruit, groente      Handel
# 3  4 Potato Holland B.V.                  Aardappels      Handel
# 4       Agrofair Benelux                       Fruit      Handel
#
#    Vrachtwagens  e-vrachtwagens  Bestelbusjes  e-bestelbusjes  \
# 0          15.0             0.0          15.0             0.0
# 1          10.0             0.0          10.0             0.0
# 2          15.0             1.0          20.0             1.0
# 3          10.0             0.0          15.0             0.0
# 4          10.0             0.0          15.0             0.0
#
#    Minimum afstand  Maximum afstand  Gemiddelde afstand  TKM Vrachtwagens  \
# 0            100.0            200.0               600.0            9000.0
# ...

# %%
bedrijven_df['kWh van diesel'] = (bedrijven_df['TKM Vrachtwagens'] * 0.30 * 9.8) + (bedrijven_df['TKM Bestelbusjes'] * 0.07 * 9.8)
bedrijven_df['kWh van e-voertuigen'] = (bedrijven_df['TKM e-vrachtwagens'] * 0.0180) + (bedrijven_df['e-bestelbusjes'] * 0.0015)
bedrijven_df['totaal kWh'] = bedrijven_df['kWh van diesel'] + bedrijven_df['kWh van e-voertuigen']

# %%
bedrijven_df.head()
# Out:
#             Bedrijfsnaam                   Producten      Sector  \
# 0            Best Trucks                Vrachtwagens  Automotive
# 1          Berkman Groep  Brandstoffen, tankstations     Energie
# 2        4 Fruit Company              Fruit, groente      Handel
# 3  4 Potato Holland B.V.                  Aardappels      Handel
# 4       Agrofair Benelux                       Fruit      Handel
#
#    Vrachtwagens  e-vrachtwagens  Bestelbusjes  e-bestelbusjes  \
# 0          15.0             0.0          15.0             0.0
# 1          10.0             0.0          10.0             0.0
# 2          15.0             1.0          20.0             1.0
# 3          10.0             0.0          15.0             0.0
# 4          10.0             0.0          15.0             0.0
#
#    Minimum afstand  Maximum afstand  Gemiddelde afstand  ...  \
# 0            100.0            200.0               600.0  ...
# 1             50.0            150.0               600.0  ...
# ...
